# %% [markdown]
# <a href="https://colab.research.google.com/github/IngridLaila/Conteudo_Didatico/blob/main/SQL/Exerc%C3%ADcios_de_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercícios:

# %% [markdown]
# Criando o banco:
#
# Create database loja_utensilios;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Selecionando o banco

# %% [markdown]
# use loja_utensilios;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Criando a tabela clientes

# %% [markdown]
# create table Cliente (
#   id_cliente INT PRIMARY KEY,
#   nome VARCHAR (50),
#   endereco VARCHAR (100)
# );

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Criação de todas as tabelas

# %% [markdown]
# SHOW TABLES;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
create table Cliente (
  id_cliente INT PRIMARY KEY,
  nome VARCHAR (50),
  endereco VARCHAR (100)
);

CREATE TABLE Pedido (
    id_pedido INT PRIMARY KEY,
    id_cliente INT,
    descricao VARCHAR(100),
    FOREIGN KEY (id_cliente) REFERENCES Cliente(id_cliente)
);

CREATE TABLE Produto (
    id_produto INT PRIMARY KEY,
    nome VARCHAR(50),
    preco DECIMAL(10, 2)
);

CREATE TABLE ItemPedido (
    id_item INT PRIMARY KEY,
    id_pedido INT,
    id_produto INT,
    quantidade INT,
    FOREIGN KEY (id_pedido) REFERENCES Pedido(id_pedido),
    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto)
);

CREATE TABLE Categoria (
    id_categoria INT PRIMARY KEY,
    nome VARCHAR(50)
);

CREATE TABLE ProdutoCategoria (
    id_produto INT,
    id_categoria INT,
    PRIMARY KEY (id_produto, id_categoria),
    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto),
    FOREIGN KEY (id_categoria) REFERENCES Categoria(id_categoria)
);
'''
# Out:
# '\ncreate table Cliente (\n  id_cliente INT PRIMARY KEY,\n  nome VARCHAR (50),\n  endereco VARCHAR (100)\n);\n\nCREATE TABLE Pedido (\n    id_pedido INT PRIMARY KEY,\n    id_cliente INT,\n    descricao VARCHAR(100),\n    FOREIGN KEY (id_cliente) REFERENCES Cliente(id_cliente)\n);\n\nCREATE TABLE Produto (\n    id_produto INT PRIMARY KEY,\n    nome VARCHAR(50),\n    preco DECIMAL(10, 2)\n);\n\nCREATE TABLE ItemPedido (\n    id_item INT PRIMARY KEY,\n    id_pedido INT,\n    id_produto INT,\n    quantidade INT,\n    FOREIGN KEY (id_pedido) REFERENCES Pedido(id_pedido),\n    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto)\n);\n\nCREATE TABLE Categoria (\n    id_categoria INT PRIMARY KEY,\n    nome VARCHAR(50)\n);\n\nCREATE TABLE ProdutoCategoria (\n    id_produto INT,\n    id_categoria INT,\n    PRIMARY KEY (id_produto, id_categoria),\n    FOREIGN KEY (id_produto) REFERENCES Produto(id_produto),\n    FOREIGN KEY (id_categoria) REFERENCES Categoria(id_categoria)\n);\n'

# %% [markdown]
# Populando tabelas

# %%
'''
INSERT INTO Cliente (id_cliente, nome, endereco)
VALUES
    (1, 'Douglas', 'SP'),
    (2, 'Daniela', 'SP'),
    (3, 'Ester', 'MG'),
    (4, 'Maria', 'BA'),
    (5, 'Douglas', 'PE'),
    (6, 'Raimundo', 'CE'),
    (7, 'Jucimara', 'GO'),
    (8, 'Marlene', 'AC'),
    (9, 'Douglas', 'MA'),
    (10, 'Daniela', 'PI'),
    (11, 'Pedro', 'PB'),
    (12, 'Joaquim', 'RS'),
    (13, 'Julio', 'TO'),
    (14, 'Carla', 'DF'),
    (15, 'Bianca', 'PA'),
    (16, 'Sandra', 'SP'),
    (17, 'Celso', 'SP'),
    (18, 'Silvana', 'BA'),
    (19, 'Prof Raquel', 'BA'),
    (20, 'Pedro', 'SP');
'''
'''
INSERT INTO Pedido (id_pedido, id_cliente, descricao)
VALUES
    (1, '1', 'Caneca'),
    (2, '1', 'Garfo'),
    (3, '2', 'Faca'),
    (4, '5', 'Copo'),
    (5, '19', 'Copo'),
    (6, '19', 'Colher'),
    (7, '15', 'Colher'),
    (8, '8', 'Colher'),
    (9, '2', 'Copo'),
    (10, '19', 'Colher'),
    (11, '6', 'Copo'),
    (12, '11', 'Colher'),
    (13, '10', 'Garfo'),
    (14, '4', 'Garfo'),
    (15, '3', 'Colher'),
    (16, '3', 'Garfo'),
    (17, '2', 'Copo'),
    (18, '17', 'Garfo'),
    (19, '14', 'Caneca'),
    (20, '13', 'Caneca');
'''
'''
INSERT INTO Produto (id_produto, nome, preco)
VALUES
    (1, 'Caneca', 15.99),
    (2, 'Garfo', 5.99),
    (3, 'Faca', 7.99),
    (4, 'Colher', 3.99),
    (5, 'Copo', 10.99);
'''

'''
INSERT INTO ItemPedido (id_item, id_pedido, id_produto, quantidade)
VALUES
    (1, 1, 1, 2),
    (2, 2, 2, 5),
    (3, 3, 3, 7),
    (4, 4, 5, 10),
    (5, 5, 5, 11),
    (6, 6, 4, 30),
    (7, 7, 4, 32),
    (8, 8, 4, 44),
    (9, 9, 5, 13),
    (10, 10, 4, 33),
    (11, 11, 5, 34),
    (12, 12, 4, 32),
    (13, 13, 2, 33),
    (14, 14, 2, 34),
    (15, 15, 4, 27),
    (16, 16, 2, 18),
    (17, 17, 5, 17),
    (18, 18, 2, 33),
    (19, 19, 1, 50),
    (20, 20, 1, 47);
'''
'''
INSERT INTO Categoria (id_categoria, nome)
VALUES
    (1, 'Comer'),
    (2, 'Beber');

INSERT INTO ProdutoCategoria (id_produto, id_categoria)
VALUES
    (1, 2),
    (2, 1),
    (3, 1),
    (4, 1),
    (5, 2);
'''

# %% [markdown]
# Select das tabelas populadas

# %% [markdown]
# SELECT * FROM Clientes;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SELECT * from ProdutoCategoria;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select especificando as colunas

# %% [markdown]
# SELECT id_produto, quantidade FROM ItemPedido;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select usando where

# %% [markdown]
# SELECT id_produto, quantidade FROM ItemPedido
# WHERE quantidade >= 10;
# Lendo o comando: Seleciona as colunas: id_produto e quantidade da tabela: ItemPedido, quando a quantidade for maior ou igual a 10
# '''
#
# '''
# SELECT * FROM Cliente
# WHERE endereco = 'SP';
#
#   Lendo o comando: Seleciona todas as colunas, quando o endereço for igual a SP

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select usando distinct

# %% [markdown]
# SELECT distinct id_produto, quantidade FROM ItemPedido
# WHERE quantidade >= 10;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select sem distinct

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select usando LIMIT

# %% [markdown]
# '''
# SELECT * FROM Cliente
# LIMIT 5;
#   Lendo o comando: Seleciona todos os atributos da tabela Cliente e mostra
#   apenas os cinco primeiros registros
# '''

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select com and, or e not

# %% [markdown]
# '''
#
# -- Exemplo de AND
# SELECT nome, endereco
# FROM Cliente
# WHERE endereco = 'BA'
# AND id_cliente = 19;
# Lendo o comando:
#    Seleciona as colunas: nome e endereco da tabela: Clientes,
#    apenas os registros com endereco igual a 'BA' e id_cliente igual a 19
#
#
# -- Exemplo de OR
# SELECT nome, endereco
# FROM Cliente
# WHERE endereco = 'SP'
# OR endereco = 'MG';
# Lendo o comando:
#    Seleciona as colunas: nome e endereco da tabela: Clientes,
#    apenas os registros com endereco igual a 'SP' ou endereco a 'MG'
#
# -- Exemplo de NOT
# SELECT nome, endereco
# FROM Clientes
# WHERE NOT endereco = 'SP';
# Lendo o comando:
#    Seleciona as colunas: nome e endereco da tabela: Clientes,
#    apenas os registros com endereco não seja igual a 'SP'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Funções de agregação

# %% [markdown]
# '''
# Somatório da quantidade de produtos vendidos
#
# SELECT SUM(quantidade) AS soma_qtde
# FROM ItemPedido;
# '''
#
# '''
# Média da quantidade de produtos vendidos
#
# SELECT AVG(quantidade) AS media_qtde,
# round(AVG(quantidade),2) AS media_qtde_arredondado
# FROM ItemPedido;
# '''
#
#
# '''
# Maior quantidade de produtos vendidos
#
# SELECT MAX(quantidade) AS maior_quantidade_venda
#   FROM ItemPedido;
# '''
# '''
# SELECT MIN(quantidade)  menor_quantidade_venda
#   FROM ItemPedido;
# '''
#
# '''
# Contagem de produtos (quantos produtos temos na nossa base?)
#
# SELECT count(id_produto) as qtd_produtos
#   FROM Produto;
# '''

# %% [markdown]
# Função sum()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Função AVG:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Função Max()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Função min()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Função count()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
