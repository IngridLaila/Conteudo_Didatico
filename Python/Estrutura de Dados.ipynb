# %% [markdown]
# <a href="https://colab.research.google.com/github/IngridLaila/Conteudo_Didatico/blob/main/Python/Estrutura%20de%20Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A alegria que se tem em pensar e aprender faz-nos pensar e aprender ainda mais.
#
# Aristóteles

# %%
# importando as principais bibliotecas para o analista de dados
import pandas as pd
import numpy as np
import scipy as sp
from statistics import *
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Estruturas de dados
#
# *   Lista
# *   Tupla
# *   Dicionário

# %%
# Listas
nomes = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idades = [45,7,65,64,37,37]
alturas = [1.85,1.23,1.75,1.67,1.82,1.73]
pesos = [70,22,87,64,96,68]

# %%
# conferindo as listas
print(nomes, idades, alturas, pesos)
# Out:
# ['Douglas', 'Daniela', 'Pedro', 'Maria', 'Eduardo', 'Ester'] [45, 7, 65, 64, 37, 37] [1.85, 1.23, 1.75, 1.67, 1.82, 1.73] [70, 22, 87, 64, 96, 68]

# %%
# Conferindo o tipo de um objeto
type(nomes)
# Out:
# list

# %%
# Acessando o elemento de índice 0 da lista nomes
print(nomes[0])
# Out:
# Douglas

# %%
# Acessando os quatro primeiros elementos da lista nomes
print(nomes[0:4]) # ou ainda
print(nomes[:4])
# Out:
# ['Douglas', 'Daniela', 'Pedro', 'Maria']
# ['Douglas', 'Daniela', 'Pedro', 'Maria']

# %%
# Percorrendo listas
for nome in nomes:
  print(nome)
# Out:
# Douglas
# Daniela
# Pedro
# Maria
# Eduardo
# Ester

# %%
print(f'{nomes[0]} tem {idades[0]} anos, {alturas[0]}m e {pesos[0]}kg')
# Out:
# Douglas tem 45 anos, 1.85m e 70kg

# %%
# Tuplas (criando tuplas, processo semelhante ao de criação de listas, mas
# ao invés de colchetes se usam parenteses)
'''
A diferença entre lista e tuplas é a mutabilidade, ou seja, as listas são
mutáveis, o que significa que você pode modificar, adicionar ou remover
elementos depois de criá-las. Por outro lado, as tuplas são imutáveis, o que
significa que, uma vez criadas, não é possível alterar seus elementos. Se você
precisar modificar uma tupla, terá que criar uma nova com os elementos
desejados. By Bianka.... apud Chat GPT
'''
nomest = ('Douglas','Daniela','Pedro','Maria','Eduardo','Ester')
idadest = tuple(idades)
alturast = tuple(alturas)
pesost = tuple(pesos)

# %%
# conferindo os tipo das tuplas
type(pesost)
# Out:
# tuple

# %%
# Transformando uma tupla em uma lista
lista = list(pesost)
type(lista)
# Out:
# list

# %%
# Acessando elementos de uma tupla
print(nomest[0]) # acessando o nome da posição 0 na tupla nomest
print(nomest[0:4]) # acessando os 4 primeiros elementos de nomest
# Out:
# Douglas
# ('Douglas', 'Daniela', 'Pedro', 'Maria')

# %%
# crie uma lista com os dois primeiros eleemntos de nomest
dois = list(nomest[0:2])
type(dois)
print(dois)
# Out:
# ['Douglas', 'Daniela']

# %%
# usando f-strings com tuplas
print(f'{nomest[0]} tem {idadest[0]} anos, {alturast[0]}m e {pesost[0]}kg')
# Out:
# Douglas tem 45 anos, 1.85m e 70kg

# %%
# Percorrendo tuplas
for nome in nomest:
  print(nome)
# Out:
# Douglas
# Daniela
# Pedro
# Maria
# Eduardo
# Ester

# %%
# Criando uma lista chamada bagunca com nomes, depois inserindo na posição 0
# dessa lista uma tupla com os mesmos nomes
bagunca = nomes
print(bagunca)
# bagunca.insert(0, nomest)
print(bagunca)
# Out:
# ['Douglas', 'Daniela', 'Pedro', 'Maria', 'Eduardo', 'Ester']
# ['Douglas', 'Daniela', 'Pedro', 'Maria', 'Eduardo', 'Ester']

# %%
# Criando dicionários
'''
Um dicionário é uma estrutura compsta por um ou mais pares de dados no sistema
de chave e valor, exemplo
dicionario = {chave1:valor1, chave2:valor2, .... chaven:valorn}
'''
id1 = {'nome':'Douglas', 'idade':45, 'altura':1.85, 'peso':70}
id2 = {'nome':'Daniela','idade':7,'altura':1.23,'peso':22}
id3 = {'nome':'Pedro','idade':65,'altura':1.75,'peso':87}
id4 = {'nome':'Maria','idade':64,'altura':1.67,'peso':64}
id5 = {'nome':'Eduardo','idade':37,'altura':1.82,'peso':96}
id6 = {'nome':'ester','idade':37,'altura':1.73,'peso':68}

# %%
# Acessando um dicionário e pegando seus valores pela chave
id1['idade'] # Acessando no dicionário id1 o valor referente a chave idade
'''
Como eu sei quais são as chaves de um dicionário?
'''
print(id1.items()) # mostra todos os pares de chave e valor de um dicionário
print(id1.keys()) # mostra todas as chaves de um dicionários
print(id1.values()) # mostra todos os valores de um dicionário
print(id1.get('idade')) # acessa um valor específico de um dicionário
# Out:
# dict_items([('nome', 'Douglas'), ('idade', 45), ('altura', 1.85), ('peso', 70)])
# dict_keys(['nome', 'idade', 'altura', 'peso'])
# dict_values(['Douglas', 45, 1.85, 70])
# 45

# %%
# Percorrendo dicionários
for k, v in id1.items():
  print(k,v)
# Out:
# nome Douglas
# idade 45
# altura 1.85
# peso 70

# %%
'''
Crie um print que acesse as informações do dicionário id1 e devolva:
Douglas tem 45 anos, 1.85m e 70kg
'''
print(f"{id1.get('nome')} tem {id1.get('idade')} anos, {id1.get('altura')}m \
e {id1.get('peso')}kg")
# Out:
# Douglas tem 45 anos, 1.85m e 70kg

# %% [markdown]
# SCIPY

# %%
#Trabalhando com a parte estatística do SciPy (estatística descritiva)

# média aritmética no SciPy
print(f' A idade média é {sp.mean(idades)} anos')

# mediana no SciPy
print(f' A idade mediana é {sp.median(idades)} anos')

# desvio padrão no SciPy (populacional)
print(f' O desvio padrão populacional é {sp.std(idades):.2f} anos')

# desvio padrão no SciPy (amostral)
print(f' O desvio padrão amostral é {sp.std(idades,ddof=1):.2f} anos')

# Variância no SciPy (populacional)
print(f' A Variância populacional é {sp.var(idades):.2f} anos')

# Variância no SciPy (amostral)
print(f' A Variância amostral é {sp.var(idades,ddof=1):.2f} anos')

# Q1 (primeiro quartil) no SciPy
print(f' O valor do Q1 é {sp.quantile(idades, 0.25):.2f} anos')

# Q2 (segundo quartil) no SciPy
print(f' O Valor do Q2 é {sp.quantile(idades, 0.5):.2f} anos')

# Q3 (terceiro quartil) no SciPy
print(f' O Valor do Q3 é {sp.quantile(idades, 0.75):.2f} anos')

# Valor máximo no SciPy
print(f' O Valor máximo é {sp.amax(idades):.2f} anos') # ou usando quantile
print(f' O Valor máximo é {sp.quantile(idades,1):.2f} anos') # ou usando quantile

# Valor mínimo no SciPy
print(f' O Valor mínimo é {sp.amin(idades):.2f} anos') # ou usando quantile
print(f' O Valor mínimo é {sp.quantile(idades,0):.2f} anos') # ou usando quantile

# Amplitude total
print(f' A amplitude total é {sp.amax(idades)-sp.amin(idades):.2f}')

# Amplitude interquartílica AIQ
print(f' A AIQ é {sp.quantile(idades, 0.75)-sp.quantile(idades, 0.25):.2f}')

# Limite inferior do boxplot
print(f' O limite inferior do box plot é {(sp.quantile(idades, 0.25))-((sp.quantile(idades, 0.75)-sp.quantile(idades, 0.25))*1.5):.2f}')

# Limite superior do boxplot
print(f' O limite superior do box plot é {(sp.quantile(idades, 0.75))+((sp.quantile(idades, 0.75)-sp.quantile(idades, 0.25))*1.5):.2f}')
# Out:
#  A idade média é 42.5 anos
#  A idade mediana é 41.0 anos
#  O desvio padrão populacional é 19.56 anos
#  O desvio padrão amostral é 21.43 anos
#  A Variância populacional é 382.58 anos
#  A Variância amostral é 459.10 anos
#  O valor do Q1 é 37.00 anos
#  O Valor do Q2 é 41.00 anos
#  O Valor do Q3 é 59.25 anos
#  O Valor máximo é 65.00 anos
#  O Valor máximo é 65.00 anos
#  O Valor mínimo é 7.00 anos
#  O Valor mínimo é 7.00 anos
#  A amplitude total é 58.00
#  A AIQ é 22.25
#  O limite inferior do box plot é 3.62
#  O limite superior do box plot é 92.62
# <ipython-input-21-58d17679795e>:4: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   print(f' A idade média é {sp.mean(idades)} anos')
# <ipython-input-21-58d17679795e>:7: DeprecationWarning: scipy.median is deprecated and will be removed in SciPy 2.0.0, use numpy.median instead
#   print(f' A idade mediana é {sp.median(idades)} anos')
# ...

# %% [markdown]
# Numpy

# %%
#Trabalhando com a parte estatística do SciPy (estatística descritiva)

# média aritmética no Numpy
print(f' A idade média é {np.mean(idades)} anos')

# mediana no Numpy
print(f' A idade mediana é {np.median(idades)} anos')

# desvio padrão no Numpy (populacional)
print(f' O desvio padrão populacional é {np.std(idades):.2f} anos')

# desvio padrão no Numpy (amostral)
print(f' O desvio padrão amostral é {np.std(idades,ddof=1):.2f} anos')

# Variância no Numpy (populacional)
print(f' A Variância populacional é {np.var(idades):.2f} anos')

# Variância no Numpy (amostral)
print(f' A Variância amostral é {np.var(idades,ddof=1):.2f} anos')

# Q1 (primeiro quartil) no Numpy
print(f' O valor do Q1 é {np.quantile(idades, 0.25):.2f} anos')

# Q2 (segundo quartil) no Numpy
print(f' O Valor do Q2 é {np.quantile(idades, 0.5):.2f} anos')

# Q3 (terceiro quartil) no Numpy
print(f' O Valor do Q3 é {np.quantile(idades, 0.75):.2f} anos')

# Valor máximo no Numpy
print(f' O Valor máximo é {np.amax(idades):.2f} anos') # ou usando quantile
print(f' O Valor máximo é {np.quantile(idades,1):.2f} anos') # ou usando quantile

# Valor mínimo no Numpy
print(f' O Valor mínimo é {np.amin(idades):.2f} anos') # ou usando quantile
print(f' O Valor mínimo é {np.quantile(idades,0):.2f} anos') # ou usando quantile

# Amplitude total
print(f' A amplitude total é {np.amax(idades)-np.amin(idades):.2f}')

# Amplitude interquartílica AIQ
print(f' A AIQ é {np.quantile(idades, 0.75)-np.quantile(idades, 0.25):.2f}')

# Limite inferior do boxplot
print(f' O limite inferior do box plot é {(np.quantile(idades, 0.25))-((np.quantile(idades, 0.75)-np.quantile(idades, 0.25))*1.5):.2f}')

# Limite superior do boxplot
print(f' O limite superior do box plot é {(np.quantile(idades, 0.75))+((np.quantile(idades, 0.75)-np.quantile(idades, 0.25))*1.5):.2f}')
# Out:
#  A idade média é 42.5 anos
#  A idade mediana é 41.0 anos
#  O desvio padrão populacional é 19.56 anos
#  O desvio padrão amostral é 21.43 anos
#  A Variância populacional é 382.58 anos
#  A Variância amostral é 459.10 anos
#  O valor do Q1 é 37.00 anos
#  O Valor do Q2 é 41.00 anos
#  O Valor do Q3 é 59.25 anos
#  O Valor máximo é 65.00 anos
#  O Valor máximo é 65.00 anos
#  O Valor mínimo é 7.00 anos
#  O Valor mínimo é 7.00 anos
#  A amplitude total é 58.00
#  A AIQ é 22.25
#  O limite inferior do box plot é 3.62
#  O limite superior do box plot é 92.62

# %%
# Link para baixar chave de acesso e guardar em arquivos no colab
# é necessário subir a chave no diretório de arquivos do colab
'https://storage.googleapis.com/chave_acesso/week-392210-b2b4c57f8027.json'

# %%
# !pip install gcsfs

# %%
from google.cloud import storage
import os
import sys
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/week-392210-b2b4c57f8027.json"

# %%
df = pd.read_csv('gs://nofx/df_bruto/xpto.csv')
display(df)
# Out:
#           data  qtde  faturamento   cv  margem  margem_ac  lucro     area  \
# 0   01/05/2023    50          500  210     290        290  -2710     Mesa
# 1   02/05/2023    40          400  168     232        522  -2478   Balcão
# 2   03/05/2023    60          600  252     348        870  -2130  Externa
# 3   04/05/2023    20          200   84     116        986  -2014   Balcão
# 4   05/05/2023    30          300  126     174       1160  -1840   Balcão
# 5   06/05/2023    30          300  126     174       1334  -1666     Mesa
# 6   07/05/2023    30          300  126     174       1508  -1492   Balcão
# 7   08/05/2023    20          200   84     116       1624  -1376   Balcão
# 8   09/05/2023    40          400  168     232       1856  -1144   Balcão
# 9   10/05/2023    30          300  126     174       2030   -970     Mesa
# 10  11/05/2023    20          200   84     116       2146   -854     Mesa
# 11  12/05/2023    60          600  252     348       2494   -506     Mesa
# ...

# %%
df.head(1)
# Out:
#          data  qtde  faturamento   cv  margem  margem_ac  lucro  area  \
# 0  01/05/2023    50          500  210     290        290  -2710  Mesa
#
#    pessoas  temperatura
# 0       12           29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   data         31 non-null     object
#  1   qtde         31 non-null     int64
#  2   faturamento  31 non-null     int64
#  3   cv           31 non-null     int64
#  4   margem       31 non-null     int64
#  5   margem_ac    31 non-null     int64
#  6   lucro        31 non-null     int64
#  7   area         31 non-null     object
#  8   pessoas      31 non-null     int64
#  9   temperatura  31 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 2.5+ KB

# %%
medidas = df.describe()
display(medidas)
# Out:
#             qtde  faturamento          cv      margem    margem_ac  \
# count  31.000000    31.000000   31.000000   31.000000    31.000000
# mean   38.709677   387.096774  162.580645  224.516129  3487.483871
# std    11.759233   117.592334   49.388780   68.203554  2014.626580
# min    20.000000   200.000000   84.000000  116.000000   290.000000
# 25%    30.000000   300.000000  126.000000  174.000000  1740.000000
# 50%    40.000000   400.000000  168.000000  232.000000  3364.000000
# 75%    50.000000   500.000000  210.000000  290.000000  5017.000000
# max    60.000000   600.000000  252.000000  348.000000  6960.000000
#
#              lucro    pessoas  temperatura
# count    31.000000  31.000000    31.000000
# mean    487.483871   9.903226    23.645161
# std    2014.626580   4.284506     5.003655
# min   -2710.000000   2.000000    15.000000
# 25%   -1260.000000   6.500000    20.000000
# 50%     364.000000  10.000000    23.000000
# 75%    2017.000000  12.500000    27.500000
# ...

# %%
# Acessando os valores numéricos do atributo qtde no df original
qtde = df['qtde']
print(type(qtde))
# Out:
# <class 'pandas.core.series.Series'>

# %%
display(qtde)
# Out:
# 0     50
# 1     40
# 2     60
# 3     20
# 4     30
# 5     30
# 6     30
# 7     20
# 8     40
# 9     30
# 10    20
# 11    60
# 12    50
# 13    40
# 14    30
# 15    30
# 16    40
# 17    50
# 18    40
# 19    40
# 20    30
# 21    20
# 22    40
# 23    50
# 24    50
# 25    50
# 26    60
# 27    40
# 28    30
# 29    40
# 30    40
# Name: qtde, dtype: int64

# %%
qtde = list(qtde)
print(qtde)
# Out:
# [50, 40, 60, 20, 30, 30, 30, 20, 40, 30, 20, 60, 50, 40, 30, 30, 40, 50, 40, 40, 30, 20, 40, 50, 50, 50, 60, 40, 30, 40, 40]

# %%
from statistics import *

# %%
# Calculando a moda de uma lista de números
mode([1,2,3,4,5,6,7,8,8,8,9,9,9,10])
# Out:
# 8

# %%
# Calculando as modas de uma lista de números
multimode([1,2,3,4,5,6,7,8,8,8,9,9,9,10])
# Out:
# [8, 9]

# %%
# Calculando a moda do atributo qtde
mdo = mode(qtde)
print(mdo)
# Out:
# 40

# %%
# Criar uma lista com o cabeçalho de um dataframe
labels = list(medidas.columns)
print(labels)
print(type(labels))
# Out:
# ['qtde', 'faturamento', 'cv', 'margem', 'margem_ac', 'lucro', 'pessoas', 'temperatura']
# <class 'list'>

# %%
moda = [] # criar uma lista vazia chamada moda
for i, v in enumerate(labels): # criar um for para percorrer i, e v da lista labels
  moda.append(mode(df[v])) # appendar na lista moda cada moda do dataframe original
print(moda) # mostrar a lista moda
# Out:
# [40, 400, 168, 232, 290, -2710, 5, 23]

# %%
medidas = medidas.reset_index() # criando um índice numérico e automaticamente fazendo com que o índice anterior vire uma coluna com os nomes das medidas
display(medidas) # mostrando
# Out:
#    index       qtde  faturamento          cv      margem    margem_ac  \
# 0  count  31.000000    31.000000   31.000000   31.000000    31.000000
# 1   mean  38.709677   387.096774  162.580645  224.516129  3487.483871
# 2    std  11.759233   117.592334   49.388780   68.203554  2014.626580
# 3    min  20.000000   200.000000   84.000000  116.000000   290.000000
# 4    25%  30.000000   300.000000  126.000000  174.000000  1740.000000
# 5    50%  40.000000   400.000000  168.000000  232.000000  3364.000000
# 6    75%  50.000000   500.000000  210.000000  290.000000  5017.000000
# 7    max  60.000000   600.000000  252.000000  348.000000  6960.000000
#
#          lucro    pessoas  temperatura
# 0    31.000000  31.000000    31.000000
# 1   487.483871   9.903226    23.645161
# 2  2014.626580   4.284506     5.003655
# 3 -2710.000000   2.000000    15.000000
# 4 -1260.000000   6.500000    20.000000
# 5   364.000000  10.000000    23.000000
# 6  2017.000000  12.500000    27.500000
# ...

# %%
moda # vizualizando a lista moda
# Out:
# [40, 400, 168, 232, 290, -2710, 5, 23]

# %%
moda.insert(0, 'moda') # inserindo a palavra moda na lista moda para que ela tenha o mesmo tamando das colunas do df medidas
print(moda)
# Out:
# ['moda', 40, 400, 168, 232, 290, -2710, 5, 23]

# %%
medidas.loc[8] = moda # inserindo a linha medidas no df medidas
display(medidas) # mostrando
# Out:
#    index       qtde  faturamento          cv      margem    margem_ac  \
# 0  count  31.000000    31.000000   31.000000   31.000000    31.000000
# 1   mean  38.709677   387.096774  162.580645  224.516129  3487.483871
# 2    std  11.759233   117.592334   49.388780   68.203554  2014.626580
# 3    min  20.000000   200.000000   84.000000  116.000000   290.000000
# 4    25%  30.000000   300.000000  126.000000  174.000000  1740.000000
# 5    50%  40.000000   400.000000  168.000000  232.000000  3364.000000
# 6    75%  50.000000   500.000000  210.000000  290.000000  5017.000000
# 7    max  60.000000   600.000000  252.000000  348.000000  6960.000000
# 8   moda  40.000000   400.000000  168.000000  232.000000   290.000000
#
#          lucro    pessoas  temperatura
# 0    31.000000  31.000000    31.000000
# 1   487.483871   9.903226    23.645161
# 2  2014.626580   4.284506     5.003655
# 3 -2710.000000   2.000000    15.000000
# 4 -1260.000000   6.500000    20.000000
# ...

# %%
dev = medidas.loc[2] # isolando a linha 2 do df medidas
print(dev) # mostrar
# Out:
# index                 std
# qtde            11.759233
# faturamento    117.592334
# cv               49.38878
# margem          68.203554
# margem_ac      2014.62658
# lucro          2014.62658
# pessoas          4.284506
# temperatura      5.003655
# Name: 2, dtype: object

# %%
sd = list(medidas.loc[2]) # transformando o df sd em uma lista sd
print(sd) # mostrando
# Out:
# ['std', 11.759233388808692, 117.59233388808691, 49.388780232996496, 68.20355365509042, 2014.6265803032868, 2014.6265803032868, 4.284505717969323, 5.003654578384178]

# %%
sd.pop(0) # removendo std da lista sd
# Out:
# 'std'

# %%
sd # conferindo se ficou joinha
# Out:
# [11.759233388808692,
#  117.59233388808691,
#  49.388780232996496,
#  68.20355365509042,
#  2014.6265803032868,
#  2014.6265803032868,
#  4.284505717969323,
#  5.003654578384178]

# %%
var = [] # criando a lista vazia var
for i in range(len(sd)): # percorrendo a lista sd
  var.append(round((sd[i]**2),2)) # appendando cada valor de sd ao quadrado na lista var
var.insert(0,'variância') # inserindo a string 'Variancia' na lista var
print(var)
# Out:
# ['variância', 138.28, 13827.96, 2439.25, 4651.72, 4058720.26, 4058720.26, 18.36, 25.04]

# %%
medidas.loc[9] = var # inserindo a lista var no df medidas
display(medidas) # mostrando
# Out:
#        index        qtde   faturamento           cv       margem  \
# 0      count   31.000000     31.000000    31.000000    31.000000
# 1       mean   38.709677    387.096774   162.580645   224.516129
# 2        std   11.759233    117.592334    49.388780    68.203554
# 3        min   20.000000    200.000000    84.000000   116.000000
# 4        25%   30.000000    300.000000   126.000000   174.000000
# 5        50%   40.000000    400.000000   168.000000   232.000000
# 6        75%   50.000000    500.000000   210.000000   290.000000
# 7        max   60.000000    600.000000   252.000000   348.000000
# 8       moda   40.000000    400.000000   168.000000   232.000000
# 9  variância  138.280000  13827.960000  2439.250000  4651.720000
#
#       margem_ac         lucro    pessoas  temperatura
# 0  3.100000e+01  3.100000e+01  31.000000    31.000000
# 1  3.487484e+03  4.874839e+02   9.903226    23.645161
# 2  2.014627e+03  2.014627e+03   4.284506     5.003655
# ...

# %%
sd = list(medidas.iloc[2])
sd.pop(0)
q1 = list(medidas.iloc[4])
q1.pop(0)
q3 = list(medidas.iloc[6])
q3.pop(0)
min = list(medidas.iloc[3])
min.pop(0)
max = list(medidas.iloc[7])
max.pop(0)
var = []
at = []
aiq = []
ls = []
li = []
for i in range(len(sd)):
  var.append(sd[i]**2)
  at.append(max[i]-min[i])
  aiq.append(q3[i]-q1[i])
  ls.append(q3[i]+(1.5*aiq[i]))
  li.append(q1[i]-(1.5*aiq[i]))
var.insert(0, 'variância')
at.insert(0, 'AT')
aiq.insert(0, 'AIQ')
ls.insert(0, 'LS')
li.insert(0, 'LI')
medidas.loc[9] = var
medidas.loc[10] = at
medidas.loc[11] = aiq
medidas.loc[12] = ls
medidas.loc[13] = li
display(medidas)
# Out:
#         index        qtde   faturamento           cv       margem  \
# 0       count   31.000000     31.000000    31.000000    31.000000
# 1        mean   38.709677    387.096774   162.580645   224.516129
# 2         std   11.759233    117.592334    49.388780    68.203554
# 3         min   20.000000    200.000000    84.000000   116.000000
# 4         25%   30.000000    300.000000   126.000000   174.000000
# 5         50%   40.000000    400.000000   168.000000   232.000000
# 6         75%   50.000000    500.000000   210.000000   290.000000
# 7         max   60.000000    600.000000   252.000000   348.000000
# 8        moda   40.000000    400.000000   168.000000   232.000000
# 9   variância  138.279570  13827.956989  2439.251613  4651.724731
# 10         AT   40.000000    400.000000   168.000000   232.000000
# 11        AIQ   20.000000    200.000000    84.000000   116.000000
# 12         LS   80.000000    800.000000   336.000000   464.000000
# ...

# %%
def eda(medidas):
  sd = list(medidas.iloc[2])
  sd.pop(0)
  q1 = list(medidas.iloc[4])
  q1.pop(0)
  q3 = list(medidas.iloc[6])
  q3.pop(0)
  min = list(medidas.iloc[3])
  min.pop(0)
  max = list(medidas.iloc[7])
  max.pop(0)
  var = []
  at = []
  aiq = []
  ls = []
  li = []
  for i in range(len(sd)):
    var.append(sd[i]**2)
    at.append(max[i]-min[i])
    aiq.append(q3[i]-q1[i])
    ls.append(q3[i]+(1.5*aiq[i]))
    li.append(q1[i]-(1.5*aiq[i]))
  var.insert(0, 'variância')
  at.insert(0, 'AT')
  aiq.insert(0, 'AIQ')
  ls.insert(0, 'LS')
  li.insert(0, 'LI')
  medidas.loc[9] = var
  medidas.loc[10] = at
  medidas.loc[11] = aiq
  medidas.loc[12] = ls
  medidas.loc[13] = li
  display(medidas)

# %%
eda(medidas)
# Out:
#         index        qtde   faturamento           cv       margem  \
# 0       count   31.000000     31.000000    31.000000    31.000000
# 1        mean   38.709677    387.096774   162.580645   224.516129
# 2         std   11.759233    117.592334    49.388780    68.203554
# 3         min   20.000000    200.000000    84.000000   116.000000
# 4         25%   30.000000    300.000000   126.000000   174.000000
# 5         50%   40.000000    400.000000   168.000000   232.000000
# 6         75%   50.000000    500.000000   210.000000   290.000000
# 7         max   60.000000    600.000000   252.000000   348.000000
# 8        moda   40.000000    400.000000   168.000000   232.000000
# 9   variância  138.279570  13827.956989  2439.251613  4651.724731
# 10         AT   40.000000    400.000000   168.000000   232.000000
# 11        AIQ   20.000000    200.000000    84.000000   116.000000
# 12         LS   80.000000    800.000000   336.000000   464.000000
# ...

# %%
medidas['index'] = medidas['index'].map({'count':'amostra','mean':'média',
'std':'desvio padrão','min':'mínimo','25%':'Q1','50%':'mediana',
'75%':'Q3','max':'máximo','moda':'moda','variância':'variância',
'AT':'AT','AIQ':'AIQ','LS':'LS','LI':'LI'})
display(medidas)
# Out:
#             index        qtde   faturamento           cv       margem  \
# 0         amostra   31.000000     31.000000    31.000000    31.000000
# 1           média   38.709677    387.096774   162.580645   224.516129
# 2   desvio padrão   11.759233    117.592334    49.388780    68.203554
# 3          mínimo   20.000000    200.000000    84.000000   116.000000
# 4              Q1   30.000000    300.000000   126.000000   174.000000
# 5         mediana   40.000000    400.000000   168.000000   232.000000
# 6              Q3   50.000000    500.000000   210.000000   290.000000
# 7          máximo   60.000000    600.000000   252.000000   348.000000
# 8            moda   40.000000    400.000000   168.000000   232.000000
# 9       variância  138.279570  13827.956989  2439.251613  4651.724731
# 10             AT   40.000000    400.000000   168.000000   232.000000
# 11            AIQ   20.000000    200.000000    84.000000   116.000000
# ...

# %%
medidas = medidas.transpose()
display(medidas)
# Out:
#                   0            1              2       3       4        5   \
# index        amostra        média  desvio padrão  mínimo      Q1  mediana
# qtde            31.0    38.709677      11.759233    20.0    30.0     40.0
# faturamento     31.0   387.096774     117.592334   200.0   300.0    400.0
# cv              31.0   162.580645       49.38878    84.0   126.0    168.0
# margem          31.0   224.516129      68.203554   116.0   174.0    232.0
# margem_ac       31.0  3487.483871     2014.62658   290.0  1740.0   3364.0
# lucro           31.0   487.483871     2014.62658 -2710.0 -1260.0    364.0
# pessoas         31.0     9.903226       4.284506     2.0     6.5     10.0
# temperatura     31.0    23.645161       5.003655    15.0    20.0     23.0
#
#                  6       7       8               9       10      11      12  \
# index            Q3  máximo    moda       variância      AT     AIQ      LS
# ...

# %%
medidas.rename(columns={0:'amostra',1:'média',
2:'desvio padrão',3:'mínimo',4:'Q1',5:'mediana',
6:'Q3',7:'máximo',8:'moda',9:'variância',10:'AT',
11:'AIQ',12:'LS',13:'LI'}, inplace=True)
medidas = medidas.drop(medidas.index[0])
display(medidas)

# %%
display(medidas)
# Out:
#             amostra        média desvio padrão  mínimo      Q1 mediana  \
# qtde           31.0    38.709677     11.759233    20.0    30.0    40.0
# faturamento    31.0   387.096774    117.592334   200.0   300.0   400.0
# cv             31.0   162.580645      49.38878    84.0   126.0   168.0
# margem         31.0   224.516129     68.203554   116.0   174.0   232.0
# margem_ac      31.0  3487.483871    2014.62658   290.0  1740.0  3364.0
# lucro          31.0   487.483871    2014.62658 -2710.0 -1260.0   364.0
# pessoas        31.0     9.903226      4.284506     2.0     6.5    10.0
# temperatura    31.0    23.645161      5.003655    15.0    20.0    23.0
#
#                  Q3  máximo    moda       variância      AT     AIQ      LS  \
# qtde           50.0    60.0    40.0       138.27957    40.0    20.0    80.0
# faturamento   500.0   600.0   400.0    13827.956989   400.0   200.0   800.0
# cv            210.0   252.0   168.0     2439.251613   168.0    84.0   336.0
# ...

# %%
medidas = medidas[['amostra','média','mediana','desvio padrão','variância',
'mínimo','Q1','Q3','máximo','AT','AIQ','LS','LI']]

# %%
medidas = medidas.transpose()
display(medidas)
# Out:
#                     qtde   faturamento           cv       margem  \
# amostra             31.0          31.0         31.0         31.0
# média          38.709677    387.096774   162.580645   224.516129
# mediana             40.0         400.0        168.0        232.0
# desvio padrão  11.759233    117.592334     49.38878    68.203554
# variância      138.27957  13827.956989  2439.251613  4651.724731
# mínimo              20.0         200.0         84.0        116.0
# Q1                  30.0         300.0        126.0        174.0
# Q3                  50.0         500.0        210.0        290.0
# máximo              60.0         600.0        252.0        348.0
# AT                  40.0         400.0        168.0        232.0
# AIQ                 20.0         200.0         84.0        116.0
# LS                  80.0         800.0        336.0        464.0
# LI                   0.0           0.0          0.0          0.0
#
# ...

# %%
medidas.reset_index(inplace=True)

# %%
medidas.rename(columns={'index':'medida'}, inplace=True)
medidas.head()
# Out:
#           medida       qtde   faturamento           cv       margem  \
# 0        amostra       31.0          31.0         31.0         31.0
# 1          média  38.709677    387.096774   162.580645   224.516129
# 2        mediana       40.0         400.0        168.0        232.0
# 3  desvio padrão  11.759233    117.592334     49.38878    68.203554
# 4      variância  138.27957  13827.956989  2439.251613  4651.724731
#
#         margem_ac           lucro    pessoas temperatura
# 0            31.0            31.0       31.0        31.0
# 1     3487.483871      487.483871   9.903226   23.645161
# 2          3364.0           364.0       10.0        23.0
# 3      2014.62658      2014.62658   4.284506    5.003655
# 4  4058720.258065  4058720.258065  18.356989   25.036559

# %%
display(medidas)
# Out:
#            medida       qtde   faturamento           cv       margem  \
# 0         amostra       31.0          31.0         31.0         31.0
# 1           média  38.709677    387.096774   162.580645   224.516129
# 2         mediana       40.0         400.0        168.0        232.0
# 3   desvio padrão  11.759233    117.592334     49.38878    68.203554
# 4       variância  138.27957  13827.956989  2439.251613  4651.724731
# 5          mínimo       20.0         200.0         84.0        116.0
# 6              Q1       30.0         300.0        126.0        174.0
# 7              Q3       50.0         500.0        210.0        290.0
# 8          máximo       60.0         600.0        252.0        348.0
# 9              AT       40.0         400.0        168.0        232.0
# 10            AIQ       20.0         200.0         84.0        116.0
# 11             LS       80.0         800.0        336.0        464.0
# 12             LI        0.0           0.0          0.0          0.0
#
# ...

# %%
medidas.to_csv('gs://nofx/df_tratado/tratado2.csv', index=False)

# %%
dados = [{'nome':'Douglas','idade':45,'altura':1.85,'peso':70},
{'nome':'Daniela','idade':7,'altura':1.23,'peso':22},
{'nome':'Pedro','idade':65,'altura':1.75,'peso':87},
{'nome':'Maria','idade':64,'altura':1.67,'peso':64},
{'nome':'Eduardo','idade':37,'altura':1.82,'peso':96},
{'nome':'ester','idade':37,'altura':1.73,'peso':68},]
print(dados)
# Out:
# [{'nome': 'Douglas', 'idade': 45, 'altura': 1.85, 'peso': 70}, {'nome': 'Daniela', 'idade': 7, 'altura': 1.23, 'peso': 22}, {'nome': 'Pedro', 'idade': 65, 'altura': 1.75, 'peso': 87}, {'nome': 'Maria', 'idade': 64, 'altura': 1.67, 'peso': 64}, {'nome': 'Eduardo', 'idade': 37, 'altura': 1.82, 'peso': 96}, {'nome': 'ester', 'idade': 37, 'altura': 1.73, 'peso': 68}]

# %%
type(dados)
# Out:
# list

# %%
normalized = pd.json_normalize(dados)
print(normalized)
# Out:
#       nome  idade  altura  peso
# 0  Douglas     45    1.85    70
# 1  Daniela      7    1.23    22
# 2    Pedro     65    1.75    87
# 3    Maria     64    1.67    64
# 4  Eduardo     37    1.82    96
# 5    ester     37    1.73    68

# %%
display(normalized)
# Out:
#       nome  idade  altura  peso
# 0  Douglas     45    1.85    70
# 1  Daniela      7    1.23    22
# 2    Pedro     65    1.75    87
# 3    Maria     64    1.67    64
# 4  Eduardo     37    1.82    96
# 5    ester     37    1.73    68

# %%
faixas_fat=['101 a 200','201 a 300','301 a 400','401 a 500','501 a 600']

# %%
df['faixas_fat'] =  pd.cut(x=df['faturamento'],bins=[100,200,300,400,500,600],labels=faixas_fat)
display(df)
# Out:
#           data  qtde  faturamento   cv  margem  margem_ac  lucro     area  \
# 0   01/05/2023    50          500  210     290        290  -2710     Mesa
# 1   02/05/2023    40          400  168     232        522  -2478   Balcão
# 2   03/05/2023    60          600  252     348        870  -2130  Externa
# 3   04/05/2023    20          200   84     116        986  -2014   Balcão
# 4   05/05/2023    30          300  126     174       1160  -1840   Balcão
# 5   06/05/2023    30          300  126     174       1334  -1666     Mesa
# 6   07/05/2023    30          300  126     174       1508  -1492   Balcão
# 7   08/05/2023    20          200   84     116       1624  -1376   Balcão
# 8   09/05/2023    40          400  168     232       1856  -1144   Balcão
# 9   10/05/2023    30          300  126     174       2030   -970     Mesa
# 10  11/05/2023    20          200   84     116       2146   -854     Mesa
# 11  12/05/2023    60          600  252     348       2494   -506     Mesa
# ...

# %%
fat = df.groupby(['faixas_fat'])['faixas_fat'].count().reset_index(name='Frequência')
display(fat)
# Out:
#   faixas_fat  Frequência
# 0  101 a 200           4
# 1  201 a 300           8
# 2  301 a 400          10
# 3  401 a 500           6
# 4  501 a 600           3

# %%
area = df.groupby(['area'])['area'].count().reset_index(name='Frequência')
display(area)
# Out:
#       area  Frequência
# 0   Balcão          12
# 1  Externa           5
# 2     Mesa          14

# %%
# !pip install pygwalker -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.2/616.2 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.3 MB/s eta 0:00:00

# %%
import pygwalker as pyg

# %%
#pyg.walk(df)

# %%
d1 = {'nome': ['Douglas', 'Daniela'], 'idade': [47, 8], 'altura': [1.85, 1.28],
'peso': [77.5, 29]}
d2 = {'nome': ['Pedro', 'Maria'], 'idade': [69, 68], 'altura': [1.75, 1.67],
'peso': [95, 65]}
d3 = {'nome': ['Eduardo', 'Ester'], 'idade': [37, 37], 'altura': [1.82, 1.73]}
d4 = {'nome': ['Eduardo', 'Ester'], 'idade': [37, 37], 'altura': [1.82, 1.73],
'peso': [92, 67]}

df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)
df3 = pd.DataFrame(d3)
df4 = pd.DataFrame(d4)
print('****************************************\n', df1)
print('****************************************\n', df2)
print('****************************************\n', df3)
print('****************************************\n', df4)

casa = pd.concat([df1, df2])

print('***************************************\n', casa)

casa2 = pd.concat([casa, df3])
print('***************************************\n', casa2)

casa3 = pd.concat([casa, df4])
print('***************************************\n', casa3)
# Out:
# ****************************************
#        nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# ****************************************
#      nome  idade  altura  peso
# 0  Pedro     69    1.75    95
# 1  Maria     68    1.67    65
# ****************************************
#        nome  idade  altura
# 0  Eduardo     37    1.82
# 1    Ester     37    1.73
# ****************************************
#        nome  idade  altura  peso
# 0  Eduardo     37    1.82    92
# 1    Ester     37    1.73    67
# ***************************************
#        nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# 0    Pedro     69    1.75  95.0
# 1    Maria     68    1.67  65.0
# ***************************************
#        nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# 0    Pedro     69    1.75  95.0
# 1    Maria     68    1.67  65.0
# ...

# %%
d1 = {'Nome': ['Douglas', 'Daniela'], 'idade': [47, 8], 'altura': [1.85, 1.28],
'peso': [77.5, 29]}
d2 = {'Nome': ['Pedro', 'Maria'], 'idade': [69, 68], 'altura': [1.75, 1.67],
'peso': [95, 65]}
d3 = {'Nome': ['Eduardo', 'Ester'], 'idade': [37, 37], 'altura': [1.82, 1.73]}
d4 = {'Nome': ['Eduardo', 'Ester'], 'idade': [37, 37], 'altura': [1.82, 1.73],
'peso': [92, 67]}

df1 = pd.DataFrame(d1)
df2 = pd.DataFrame(d2)
df3 = pd.DataFrame(d3)
df4 = pd.DataFrame(d4)
print('****************************************\n', df1)
print('****************************************\n', df2)
print('****************************************\n', df3)
print('****************************************\n', df4)

casa = pd.concat([df1, df2], ignore_index=True)

print('***************************************\n', casa)

casa2 = pd.concat([casa, df3], ignore_index=True)
print('***************************************\n', casa2)

casa3 = pd.concat([casa, df4], ignore_index=True)
print('***************************************\n', casa3)
# Out:
# ****************************************
#        Nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# ****************************************
#      Nome  idade  altura  peso
# 0  Pedro     69    1.75    95
# 1  Maria     68    1.67    65
# ****************************************
#        Nome  idade  altura
# 0  Eduardo     37    1.82
# 1    Ester     37    1.73
# ****************************************
#        Nome  idade  altura  peso
# 0  Eduardo     37    1.82    92
# 1    Ester     37    1.73    67
# ***************************************
#        Nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# 2    Pedro     69    1.75  95.0
# 3    Maria     68    1.67  65.0
# ***************************************
#        Nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# 2    Pedro     69    1.75  95.0
# 3    Maria     68    1.67  65.0
# ...

# %%
casa2['peso'].fillna(casa2['peso'].mean())
# Out:
# 0    77.500
# 1    29.000
# 2    95.000
# 3    65.000
# 4    66.625
# 5    66.625
# Name: peso, dtype: float64

# %%
casa2.iat[4,3] = 92 # para substituir o NaN da linha 4
casa2.iat[5,3] = 67 # para substituir o NaN da linha 5
print('***************************************\n', casa3)
# Out:
# ***************************************
#        Nome  idade  altura  peso
# 0  Douglas     47    1.85  77.5
# 1  Daniela      8    1.28  29.0
# 2    Pedro     69    1.75  95.0
# 3    Maria     68    1.67  65.0
# 4  Eduardo     37    1.82  92.0
# 5    Ester     37    1.73  67.0

# %%
'''
Nesse bloco o objetivo é criar uma coluna chamada de imc, essa coluna vai ser
calculada com base nas colunas peso e altura, além disso, é criada com a função
assign e utilizamos em conjunto com a função round (para arredondar os valores
em duas casas decimais)
'''
casa3 = round(casa3.assign(imc=(casa3['peso']/(casa3['altura']**2))),2)
display(casa3)
# Out:
#       Nome  idade  altura  peso    imc
# 0  Douglas     47    1.85  77.5  22.64
# 1  Daniela      8    1.28  29.0  17.70
# 2    Pedro     69    1.75  95.0  31.02
# 3    Maria     68    1.67  65.0  23.31
# 4  Eduardo     37    1.82  92.0  27.77
# 5    Ester     37    1.73  67.0  22.39

# %%
js = casa3.to_json(orient = 'records')
js
# Out:
# '[{"Nome":"Douglas","idade":47,"altura":1.85,"peso":77.5,"imc":22.64},{"Nome":"Daniela","idade":8,"altura":1.28,"peso":29.0,"imc":17.7},{"Nome":"Pedro","idade":69,"altura":1.75,"peso":95.0,"imc":31.02},{"Nome":"Maria","idade":68,"altura":1.67,"peso":65.0,"imc":23.31},{"Nome":"Eduardo","idade":37,"altura":1.82,"peso":92.0,"imc":27.77},{"Nome":"Ester","idade":37,"altura":1.73,"peso":67.0,"imc":22.39}]'

# %%
correl = casa3.corr()
# Out:
# <ipython-input-87-d2b221fb720c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correl = casa3.corr()

# %%
print(correl)
# Out:
#            idade    altura      peso       imc
# idade   1.000000  0.636169  0.683018  0.690787
# altura  0.636169  1.000000  0.898452  0.669234
# peso    0.683018  0.898452  1.000000  0.922559
# imc     0.690787  0.669234  0.922559  1.000000

# %%
rquad = 0.898452**2
print(rquad)
# Out:
# 0.8072159963040001

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(correl, annot=True)
plt.show()

# %%
banco = pd.read_csv('gs://nofx/df_bruto/banco_xpto.csv')
display(banco)
# Out:
#                 periodo   ativo      pl  lucro   roe  ipca  igpm  dolar  euro  \
# 0   2022-06-30 00:00:00  217.11  151.24   7.47  0.05  0.02  0.02   0.11  0.04
# 1   2022-03-31 00:00:00  203.16  144.69   6.99  0.05  0.03  0.05  -0.15 -0.17
# 2   2021-12-31 00:00:00  218.46  144.56   7.72  0.05  0.03  0.02   0.03  0.00
# 3   2021-09-30 00:00:00  216.47  136.81   5.72  0.04  0.03  0.01   0.09  0.06
# 4   2021-06-30 00:00:00  203.58  136.04   7.39  0.05  0.02  0.06  -0.12 -0.11
# 5   2021-03-31 00:00:00  214.81  140.51   5.41  0.04  0.02  0.08   0.10  0.05
# 6   2020-12-31 00:00:00  210.40  136.70   7.64  0.06  0.03  0.08  -0.08 -0.04
# 7   2020-09-30 00:00:00  206.00  130.67   4.61  0.04  0.01  0.10   0.03  0.07
# 8   2020-06-30 00:00:00  199.99  126.42   4.84  0.04  0.00  0.03   0.05  0.07
# 9   2020-03-31 00:00:00  197.92  123.89   1.88  0.02  0.01  0.02   0.29  0.26
# 10  2019-12-31 00:00:00  182.35  132.24   8.26  0.06  0.02  0.03  -0.03  0.00
# ...
